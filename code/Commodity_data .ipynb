# %% [markdown]
# # Input Details

# %%
# EXCHANGES
#https://www.investing.com/indices/us-30-futures-historical-data
US30 = {
'name' : 'US30',
'curr_id': 8873,
'smlID':500138 ,
'header' : 'Dow Jones 30 Contract',
'sort_col' : 'date',
'action' : 'historical_data'
}

#https://www.investing.com/indices/volatility-s-p-500
VIX = {
'name' : 'VIX',
'curr_id':44336 ,
'smlID': 2059974,
'header' : 'CBOE Volatility Index',
'sort_col' : 'date',
'action' : 'historical_data'
}
 
#https://www.investing.com/indices/bloomberg-commodity-historical-data
BCOM = {
'name' : 'BCOM',
'curr_id':948434 ,
'smlID': 2076501,
'header' : 'Bloomberg Commodity',
'sort_col' : 'date',
'action' : 'historical_data'
}
    
#https://www.investing.com/indices/us-spx-500-futures-historical-data
US500 = {
'name' : 'US500',
'curr_id': 8839,
'smlID': 500066,
'header' : 'S&P 500 Contract',
'sort_col' : 'date',
'action' : 'historical_data'
}

#FOREX
#https://www.investing.com/currencies/jpy-usd-historical-data
JPYUSD = {
'name' : 'JPYUSD',
'curr_id': 1910,
'smlID': 300196,
'header' : 'Japanese Yen US Dollar',
'sort_col' : 'date',
'action' : 'historical_data'
}

#https://www.investing.com/currencies/cad-usd-historical-data
CADUSD = {
'name' : 'CADUSD',
'curr_id': 1538,
'smlID': 106872,
'header' : 'Canadian Dollar US Dollar',
'sort_col' : 'date',
'action' : 'historical_data'
}

#https://www.investing.com/currencies/inr-usd-historical-data
INRUSD = {
'name' : 'INRUSD',
'curr_id': 941148,
'smlID': 128650,
'header' : 'Indian Rupee US Dollar',
'sort_col' : 'date',
'action' : 'historical_data'
}

#https://www.investing.com/currencies/aud-usd
AUDUSD = {
'name' : 'AUDUSD',
'curr_id': 5,
'smlID': 106686,
'header' : 'Australian Dollar US Dollar',
'sort_col' : 'date',
'action' : 'historical_data'
}

#https://www.investing.com/currencies/gbp-usd
GBPUSD = {
'name' : 'GBPUSD',
'curr_id': 2,
'smlID': 106683,
'header' : 'British Pound US Dollar',
'sort_col' : 'date',
'action' : 'historical_data'
}

#METALS

#https://www.investing.com/commodities/gold-historical-data
GCG8 = {
'name' : 'GCG8',
'curr_id': 8830,
'smlID': 300004,
'header' : 'Gold Futures Historical Data',
'sort_col' : 'date',
'action' : 'historical_data'
}

#https://www.investing.com/commodities/copper-historical-data
HGH8 = {
'name' : 'HGH8',
'curr_id': 8831,
'smlID': 300012,
'header' : 'Copper Futures Historical Data',
'sort_col' : 'date',
'action' : 'historical_data'
}

#https://www.investing.com/commodities/silver-historical-data
SIH8 = {
'name' : 'SIH8',
'curr_id': 8836,
'smlID': 300044,
'header' : 'Silver Futures Historical Data',
'sort_col' : 'date',
'action' : 'historical_data'
}

#https://www.investing.com/commodities/natural-gas-historical-data



#https://www.investing.com/commodities/us-corn-historical-data
ZCN9 = {
'name' : 'ZCN9',
'curr_id': 8918,
'smlID': 300196,
'header' : 'US Corn Futures Historical Data',
'sort_col' : 'date',
'action' : 'historical_data'
}


# https://www.investing.com/commodities/aluminum
MALTR = {
'name' : 'MALTR',
'curr_id': 49768,
'smlID': 300586,
'header' : 'Aluminum Futures Historical Data',
'sort_col' : 'date',
'action' : 'historical_data'
}

# https://www.investing.com/commodities/crude-oil-historical-data
CLN9 = {
'name' : 'CLN9',
'curr_id': 8849,
'smlID': 300060,
'header' : 'Crude Oil WTI Futures Historical Data',
'sort_col' : 'date',
'action' : 'historical_data'
}

# https://www.investing.com/commodities/gasoline-rbob-historical-data

RBN9 = {
'name' : 'RBN9',
'curr_id': 954867,
'smlID': 300912,
'header' : 'Gasoline RBOB Futures Historical Data',
'sort_col' : 'date',
'action' : 'historical_data'
}

# https://www.investing.com/commodities/heating-oil-historical-data 

HON9 = {
'name' : 'HON9',
'curr_id': 8988,
'smlID': 300212,
'header' : 'Heating Oil Futures Historical Data',
'sort_col' : 'date',
'action' : 'historical_data'
}


# https://www.investing.com/commodities/us-sugar-no11-historical-data
SBN9 = {
'name' : 'SBN9',
'curr_id': 8869,
'smlID': 300100,
'header' : 'US Sugar #11 Futures',
'sort_col' : 'date',
'action' : 'historical_data'
}


# https://www.investing.com/commodities/us-coffee-c-historical-data
KCN9 = {
'name' : 'KCN9',
'curr_id': 8832,
'smlID': 300020,
'header' : 'US Coffee C Futures',
'sort_col' : 'date',
'action' : 'historical_data'
}

# https://www.investing.com/commodities/us-cocoa-historical-data
CCN9 = {
    
'name' : 'CCN9',
'curr_id': 8894,
'smlID': 300124,
'header' : 'US Cocoa Futures',
'sort_col' : 'date',
'action' : 'historical_data'
}

# https://www.investing.com/commodities/rough-rice-historical-data
RRN9 = {
'name' : 'RRN9',
'curr_id': 13916,
'smlID': 300409,
'header' : 'Rough Rice Futures',
'sort_col' : 'date',
'action' : 'historical_data'
}

# https://www.investing.com/commodities/live-cattle-historical-data
LEQ9 = {
'name' : 'LEQ9',
'curr_id': 8914,
'smlID': 300164,
'header' : 'Live Cattle Futures',
'sort_col' : 'date',
'action' : 'historical_data'
}

# https://www.investing.com/commodities/lean-hogs-historical-data
HEM9 = {
'name' : 'HEM9',
'curr_id': 8913,
'smlID': 300925,
'header' : 'lean-hogs-historical-data',
'sort_col' : 'date',
'action' : 'historical_data'
}

# https://www.investing.com/commodities/feed-cattle-historical-data
FCQ9 = {
'name' : 'FCQ9',
'curr_id': 961618,
'smlID': 300996,
'header' : 'Feeder Cattle Futures',
'sort_col' : 'date',
'action' : 'historical_data'
}

# https://www.investing.com/commodities/class-iii-milk-futures-historical-data
DCSc1 = {
'name' : 'DCSc1',
'curr_id': 961735,
'smlID': 301081,
'header' : 'Class III Milk Futures',
'sort_col' : 'date',
'action' : 'historical_data'
}

# https://www.investing.com/commodities/us-cotton-no.2
CTN9 = {
'name' : 'CTN9',
'curr_id': 8851,
'smlID': 300068,
'header' : 'US Cotton #2 Futures',
'sort_col' : 'date',
'action' : 'historical_data'
}

# https://www.investing.com/commodities/us-wheat-historical-data
ZWN9 = {
'name' : 'ZWN9',
'curr_id': 8917,
'smlID': 300188,
'header' : 'US Wheat Futures',
'sort_col' : 'date',
'action' : 'historical_data'
}

# https://www.investing.com/commodities/us-soybean-oil-historical-data
ZLN9 = {
'name' : 'ZLN9',
'curr_id': 8915,
'smlID': 300172,
'header' : 'US Soybean Oil Futures',
'sort_col' : 'date',
'action' : 'historical_data'
}

# https://www.investing.com/commodities/us-soybean-meal-historical-data
ZMN9 = {
'name' : 'ZMN9',
'curr_id': 8919,
'smlID': 300204,
'header' : 'US Soybean Meal Futures',
'sort_col' : 'date',
'action' : 'historical_data'
}

# https://www.investing.com/commodities/oats-historical-data
Oc1 = {
'name' : 'Oc1',
'curr_id': 959199,
'smlID': 300971,
'header' : 'Oats Futures',
'sort_col' : 'date',
'action' : 'historical_data'
}

# https://www.investing.com/commodities/us-soybeans-historical-data
ZSN9 = {
'name' : 'ZSN9',
'curr_id': 8916,
'smlID': 300180,
'header' : 'US Soybeans Futures',
'sort_col' : 'date',
'action' : 'historical_data'
}

# https://www.investing.com/commodities/copper-historical-data
HGN9 = {
'name' : 'HGN9',
'curr_id': 8831,
'smlID': 300012,
'header' : 'Copper Futures',
'sort_col' : 'date',
'action' : 'historical_data'
}

# https://www.investing.com/commodities/gold-historical-data
GCQ9  = {
'name' : 'GCQ9',
'curr_id': 8830,
'smlID': 300004,
'header' : 'Gold Futures',
'sort_col' : 'date',
'action' : 'historical_data'
}

# https://www.investing.com/commodities/silver-historical-data
SIN9 = {
'name' : 'SIN9',
'curr_id': 8836,
'smlID': 300044,
'header' : 'Silver Futures',
'sort_col' : 'date',
'action' : 'historical_data'
}

# https://www.investing.com/commodities/platinum-historical-data
PLN9 = {
'name' : 'PLN9',
'curr_id': 8910,
'smlID': 300132,
'header' : 'Platinum Futures',
'sort_col' : 'date',
'action' : 'historical_data'
}

# https://www.investing.com/commodities/palladium
PAU9 = {
'name' : 'PAU9',
'curr_id': 8883,
'smlID': 300108,
'header' : 'Palladium Contract',
'sort_col' : 'date',
'action' : 'historical_data'
}

# https://www.investing.com/commodities/feed-cattle-historical-data
FCQ9 = {
'name' : 'FCQ9',
'curr_id': 961618,
'smlID': 300996,
'header' : 'Feeder Cattle Futures',
'sort_col' : 'date',
'action' : 'historical_data'
}

#https://www.investing.com/indices/sp-gsci-commodity-total-return
SPGSCITR = {
'name' : 'SPGSCITR',
'curr_id': 999050,
'smlID': 2151500,
'header' : 'S&P GSCI Commodity Total Return',
'sort_col' : 'date',
'action' : 'historical_data'
}

# %% [markdown]
# ## https://www.investing.com/commodities/real-time-futures

# %% [markdown]
# # Monthly Download

# %%
from lxml.etree import fromstring
import pandas as pd
import calendar, requests

headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36', #required 
    'referer': "https://www.investing.com/commodities/us-corn-historical-data",
    'host' : 'www.investing.com',
    'X-Requested-With' : 'XMLHttpRequest'
}

class IndiceHistoricalData():    
    
    def __init__(self, API_url):
        self.API_url = API_url

    #set https header for request
    def setHeaders(self, headers):
        self.headers = headers 
    
    #set indice data (indices.py) 
    def setFormData(self, data):
        self.data = data 

    def updateFrequency(self, frequency):
        self.data['interval_sec'] = frequency     
        
    def updateStartingEndingDate(self, startingDate, endingDate):
        self.data['st_date'] = startingDate     
        self.data['end_date'] = endingDate     

    def setSortColumns(self, sorting_columns):
        self.data['sort_col'] = sorting_columns

    def setSortOreder(self, sorting_order):
        self.data['sort_ord'] = sorting_order   

    def downloadData(self):
        self.response = requests.post(self.API_url, data=self.data, headers=self.headers).content
        self.observations = pd.read_html(self.response)[0]
        return self.observations

    def printData(self):
        print(type(self.observations['Date']))# = self.observations['Date'].replace(" ","-")
        print(self.observations)

    def saveDataCSV(self):
        #print(str(self.observations['Date']).replace(" ",""))
        self.observations['Date'] = "28-"+self.observations['Date'].str.replace(" ","-")
        #print(self.observations['Date'].strftime("%m-%d-%Y"))
        #self.observations['Date'] = 'date:'+self.observations['Date']
        
        self.observations['Date'] = pd.to_datetime(self.observations['Date'],errors = 'coerce')
        #print(self.observations['Date'])
        #self.observations['Date'] = self.observations['Date'].dt.strftime("%m_%d_%Y")
        self.observations.to_csv('./indices/'+self.data['header']+" ("+self.data['name']+")"+'.csv', sep=',', encoding='utf-8',index=False)
        print('./indices/'+self.data['header']+" ("+self.data['name']+")"+'.csv')
        #return self.observations

lst = [GCG8, HGH8, SIH8, NGF8, ZCN9,\
         MALTR, CLN9, RBN9, HON9, SBN9,\
         KCN9, CCN9, RRN9, LEQ9, HEM9, \
         FCQ9, DCSc1, CTN9, ZWN9, ZLN9, \
         Oc1, ZSN9, HGN9, GCQ9, SIN9, PLN9, PAU9]
        
lst =[JPYUSD,CADUSD,INRUSD,AUDUSD,GBPUSD,US30,VIX,BCOM,US500]
lst =[SPGSCITR]

for i in lst:
    ihd = IndiceHistoricalData('https://www.investing.com/instruments/HistoricalDataAjax')
    ihd.setHeaders(headers)
    ihd.setFormData(i)
    
    ihd.updateFrequency('Daily')
    ihd.updateFrequency('Monthly')
    ihd.updateStartingEndingDate('01/01/1980', '12/20/2019')
    #ihd.updateStartingEndingDate('06/21/2019', '06/22/2019')
    ihd.setSortOreder('ASC')
    ihd.setSortColumns('date')
    ihd.downloadData()
    #ihd.printData()
    ihd.saveDataCSV()
# Out:
# ./indices/S&P GSCI Commodity Total Return (SPGSCITR).csv

# %% [markdown]
# # Daily Data Download

# %%
from lxml.etree import fromstring
import pandas as pd
import calendar, requests

headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36', #required 
    'referer': "https://www.investing.com/commodities/us-corn-historical-data",
    'host' : 'www.investing.com',
    'X-Requested-With' : 'XMLHttpRequest'
}

class IndiceHistoricalData():    
    
    def __init__(self, API_url):
        self.API_url = API_url

    #set https header for request
    def setHeaders(self, headers):
        self.headers = headers 
    
    #set indice data (indices.py) 
    def setFormData(self, data):
        self.data = data 

    def updateFrequency(self, frequency):
        self.data['interval_sec'] = frequency     
        
    def updateStartingEndingDate(self, startingDate, endingDate):
        self.data['st_date'] = startingDate     
        self.data['end_date'] = endingDate     

    def setSortColumns(self, sorting_columns):
        self.data['sort_col'] = sorting_columns

    def setSortOreder(self, sorting_order):
        self.data['sort_ord'] = sorting_order   

    def downloadData(self):
        self.response = requests.post(self.API_url, data=self.data, headers=self.headers).content
        self.observations = pd.read_html(self.response)[0]
        return self.observations

    def printData(self):
        print(type(self.observations['Date']))# = self.observations['Date'].replace(" ","-")
        print(self.observations)

    def saveDataCSV(self):
        #print(str(self.observations['Date']).replace(" ",""))
        self.observations['Date'] = "28-"+self.observations['Date'].str.replace(" ","-")
        #print(self.observations['Date'].strftime("%m-%d-%Y"))
        #self.observations['Date'] = 'date:'+self.observations['Date']
        
        self.observations['Date'] = pd.to_datetime(self.observations['Date'],errors = 'coerce')
        #print(self.observations['Date'])
        #self.observations['Date'] = self.observations['Date'].dt.strftime("%m_%d_%Y")
        self.observations.to_csv('./indices/'+self.data['header']+" ("+self.data['name']+")"+'.csv', sep=',', encoding='utf-8',index=False)
        #return self.observations

lst = [GCG8, HGH8, SIH8, NGF8, ZCN9,\
        MALTR, CLN9, RBN9, HON9, SBN9,\
         KCN9, CCN9, RRN9, LEQ9, HEM9, \
         FCQ9, DCSc1, CTN9, ZWN9, ZLN9, \
         Oc1, ZSN9, HGN9, GCQ9, SIN9, PLN9, PAU9]
        
#lst =[GCQ9]

lst =[JPYUSD,CADUSD,INRUSD,AUDUSD,GBPUSD,US30,VIX,BCOM,US500]

lst =[FCQ9]

lst =[SPGSCITR]

# ls_ =['01/01/1980', '01/01/1985'], ['01/01/1985', '01/01/1990'],['01/01/1990', '01/01/1995'],\
# ['01/01/1995', '01/01/2000'], ['01/01/2000', '01/01/2005'],['01/01/2005', '01/01/2010'],\
# ['01/01/2010', '01/01/2015'], ['01/01/2015', '01/01/2020']

ls_ =[['01/01/1980', '01/01/1995'], ['01/01/1995', '01/01/2010'],['01/01/2010', '01/01/2020']]

# ls_ =['01/01/1980', '01/01/1985'], ['01/01/1985', '01/01/1990'],['01/01/1990', '01/01/1995'],\
# ['01/01/1995', '01/01/2000'], ['01/01/2000', '01/01/2005'],['01/01/2005', '01/01/2010'],\
# ['01/01/2010', '01/01/2015'], ['01/01/2015', '01/01/2020']

import time
import datetime
for i in lst:
    print('started'+i['name'],datetime.datetime.now())
    ihd = IndiceHistoricalData('https://www.investing.com/instruments/HistoricalDataAjax')
    ihd.setHeaders(headers)
    ihd.setFormData(i)
    
    ihd.updateFrequency('Daily')
    #ihd.updateFrequency('Monthly')
    data_collect =[]
    for j in ls_:
        st_1 = j[0]
        st_2 = j[1]
        ihd.updateStartingEndingDate(st_1, st_2)
        #ihd.updateStartingEndingDate('06/21/2019', '06/22/2019')
        ihd.setSortOreder('ASC')
        ihd.setSortColumns('date')
        data_collect.append(ihd.downloadData())
    t = pd.concat(data_collect, axis=0)
    t=t.dropna(subset=['Price'])
    t['Date'] = pd.to_datetime(t['Date'])
    t = t.sort_values('Date')
    t.to_csv('./indices/'+i['header']+" ("+i['name']+")"+'.csv', sep=',', encoding='utf-8',index=False)
    print(time)
    print('sleeping',datetime.datetime.now())
    time.sleep(5)
        #ihd.printData()
        #ihd.saveDataCSV()
# Out:
# startedSPGSCITR 2019-07-28 17:56:03.280819
# <module 'time' (built-in)>
# sleeping 2019-07-28 17:56:08.479809

# %%
'./indices/'+i['header']+" ("+i['name']+")"+'.csv'
# Out:
# './indices/S&P GSCI Commodity Total Return (SPGSCITR).csv'
